# %% [markdown]
# # Zeta-Mass Pullback Calibration (Reproducible)
#
# This notebook runs the predeclared experiment and reports whether the data support a success claim.

# %%
from pathlib import Path
import csv
import json
import subprocess

# %%
root = Path.cwd()
script = root / 'scripts' / 'run_calibration.py'
result = subprocess.run(['python', str(script)], check=True, capture_output=True, text=True)
print(result.stdout)

# %%
with (root / 'results' / 'summary.csv').open() as f:
    rows = list(csv.DictReader(f))
rows

# %%
report = json.loads((root / 'results' / 'report.json').read_text())
report

# %% [markdown]
# ## Falsification policy
# A success claim is allowed only when **all** predeclared criteria pass for every assignment rule.
